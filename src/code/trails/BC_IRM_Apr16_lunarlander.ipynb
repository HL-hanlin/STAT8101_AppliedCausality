# %%
from google.colab import drive
drive.mount('/content/drive')


import os

import torch
os.chdir('/content/drive/MyDrive/ImitationLearning/Invariant-Causal-Imitation-Learning-main/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # load

# %%
# !pip install mpi4py 
# !pip install box2d-py
# !pip install box2d 
# !pip3 install gym[Box_2D] 
# !pip install gym==0.17.2 -qqq
# !pip install numpy~=1.18.2 -qqq
# !pip install pandas~=1.0.4 -qqq
# !pip install PyYAML~=5.4.1 -qqq
# !pip install scikit-learn~=0.22.2 -qqq
# !pip install scipy~=1.1.0 -qqq
# !pip install stable-baselines~=2.10.1 -qqq
# !pip install tensorflow~=1.15.0 -qqq
# !pip install torch>=1.6.0 -qqq
# !pip install tqdm~=4.32.1 -qqq
# Out:
# Requirement already satisfied: mpi4py in /usr/local/lib/python3.7/dist-packages (3.1.3)
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.7/dist-packages (2.3.8)
# Requirement already satisfied: box2d in /usr/local/lib/python3.7/dist-packages (2.3.10)
# Requirement already satisfied: gym[Box_2D] in /usr/local/lib/python3.7/dist-packages (0.17.2)
# WARNING: gym 0.17.2 does not provide the extra 'box_2d'
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.1.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.18.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.5.0)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[Box_2D]) (0.16.0)

# %% [markdown]
# #config

# %%
config = {
    "ENV": "CartPole-v1",
    "ALG": "BCIRMStudent_Apr17",
    "NUM_TRAJS_GIVEN": 20, #
    "NUM_TRAINING_ENVS": 2,
    "NOISE_DIM": 4,
    "REP_SIZE": 16,
    "TRAJ_SHIFT": 20, # 20,
    "SAMPLING_RATE": 5,
    "NUM_STEPS_TRAIN": 10000,
    "NUM_TRAJS_VALID": 100,
    "NUM_REPETITIONS": 15,
    "BATCH_SIZE": 64,
    "MLP_WIDTHS": 64,
    "ADAM_ALPHA": 1e-3,
    "SGLD_BUFFER_SIZE": 10000,
    "SGLD_LEARN_RATE": 0.01,
    "SGLD_NOISE_COEF": 0.01,
    "SGLD_NUM_STEPS": 100,
    "SGLD_REINIT_FREQ": 0.05,
    "NUM_STEPS_TRAIN_ENERGY_MODEL": 1000,
    'TRIAL': 0
}


config['ENV'] = "LunarLander-v2"
#config['ENV'] = "CartPole-v1"

config['METHOD'] = "BCIRM"
#config['METHOD'] = "BC"



if config['METHOD'] == 'BCIRM':
    config['l2_regularizer_weight'] = 0.001
    config['penalty_weight'] = 10000
    config['penalty_anneal_iters'] = 2500

# %% [markdown]
# #testing/il

# %%
import argparse
import os
import pickle

import gym
import numpy as np
import pandas as pd
import yaml
import numpy as np

try:
    from paths import get_model_path, get_trajs_path  # noqa
except (ModuleNotFoundError, ImportError):
    from testing.paths import get_model_path, get_trajs_path  # pylint: disable=reimported

from contrib.energy_model import EnergyModel
from contrib.env_wrapper import EnvWrapper, get_test_mult_factors
from network import (
    EnvDiscriminator,
    FeaturesDecoder,
    FeaturesEncoder,
    MineNetwork,
    ObservationsDecoder,
    StudentNetwork,
)
from student import ICILStudent, BCStudent, BCIRMStudent
from testing.train_utils import fill_buffer, make_agent, save_results
# Out:
# /usr/local/lib/python3.7/dist-packages/stable_baselines/__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %% [markdown]
# # make student

# %%
env = gym.make(config["ENV"])
env.action_space.n
# Out:
# 4

# %%
# pylint: disable=redefined-outer-name
def make_student(run_seed, config):
    env = gym.make(config["ENV"])
    trajs_path = get_trajs_path(config["ENV"], "student_" + config["ALG"], env_id="student", run_seed=run_seed)
    model_path = get_model_path(config["ENV"], "student_" + config["ALG"], run_seed=run_seed)

    state_dim = env.observation_space.shape[0] + config["NOISE_DIM"]
    action_dim = env.action_space.n
    num_training_envs = config["NUM_TRAINING_ENVS"]

    # run_seed = run_seed
    batch_size = config["BATCH_SIZE"]
    teacher = make_agent(config["ENV"], config["EXPERT_ALG"], config["NUM_TRAINING_ENVS"])
    teacher.load_pretrained()

    buffer = fill_buffer(
        trajs_path=teacher.trajs_paths,
        batch_size=batch_size,
        run_seed=run_seed,
        traj_shift=config["TRAJ_SHIFT"],
        buffer_size_in_trajs=config["NUM_TRAJS_GIVEN"],
        sampling_rate=config["SAMPLING_RATE"],
    )

    if buffer.total_size < batch_size:
        batch_size = buffer.total_size



    ##########################      COMMON      ##########################

    print("state_dim", state_dim)

    causal_features_encoder = FeaturesEncoder(
        input_size=state_dim, representation_size=config["REP_SIZE"], width=config["MLP_WIDTHS"]
    )

    policy_network = StudentNetwork(in_dim=config["REP_SIZE"], out_dim=action_dim, width=config["MLP_WIDTHS"])

    #print("config method = ", config['METHOD'])


    ##########################       BC       #######################

    if config['METHOD'] == 'BC':

        return BCStudent(
            env=env,
            trajs_paths=trajs_path,
            model_path=model_path,
            num_training_envs=num_training_envs,
            teacher=teacher,
            causal_features_encoder=causal_features_encoder,
            policy_network=policy_network,
            buffer=buffer,
            adam_alpha=config["ADAM_ALPHA"],
            config = config
        )


    ##########################       BC IRM       #######################


    elif config['METHOD'] == 'BCIRM':

        return BCIRMStudent(
            env=env,
            trajs_paths=trajs_path,
            model_path=model_path,
            num_training_envs=num_training_envs,
            teacher=teacher,
            causal_features_encoder=causal_features_encoder,
            policy_network=policy_network,
            buffer=buffer,
            adam_alpha=config["ADAM_ALPHA"],
            config = config
        )

    ##########################       ICIL        #######################

    elif config['METHOD'] == 'ICIL':
        energy_model = EnergyModel(
            in_dim=state_dim,
            width=config["MLP_WIDTHS"],
            batch_size=batch_size,
            adam_alpha=config["ADAM_ALPHA"],
            buffer=buffer,
            sgld_buffer_size=config["SGLD_BUFFER_SIZE"],
            sgld_learn_rate=config["SGLD_LEARN_RATE"],
            sgld_noise_coef=config["SGLD_NOISE_COEF"],
            sgld_num_steps=config["SGLD_NUM_STEPS"],
            sgld_reinit_freq=config["SGLD_REINIT_FREQ"],
        )
        energy_model.train(num_updates=config["NUM_STEPS_TRAIN_ENERGY_MODEL"])


        causal_features_decoder = FeaturesDecoder(
            action_size=action_dim, representation_size=config["REP_SIZE"], width=config["MLP_WIDTHS"]
        )

        observations_decoder = ObservationsDecoder(
            representation_size=config["REP_SIZE"], out_size=state_dim, width=config["MLP_WIDTHS"]
        )


        env_discriminator = EnvDiscriminator(
            representation_size=config["REP_SIZE"], num_envs=config["NUM_TRAINING_ENVS"], width=config["MLP_WIDTHS"]
        )

        noise_features_encoders = [
            FeaturesEncoder(input_size=state_dim, representation_size=config["REP_SIZE"], width=config["MLP_WIDTHS"])
            for i in range(num_training_envs)
        ]
        noise_features_decoders = [
            FeaturesDecoder(action_size=action_dim, representation_size=config["REP_SIZE"], width=config["MLP_WIDTHS"])
            for i in range(num_training_envs)
        ]

        print(noise_features_decoders)

        mine_network = MineNetwork(x_dim=config["REP_SIZE"], z_dim=config["REP_SIZE"], width=config["MLP_WIDTHS"])

        return ICILStudent(
            env=env,
            trajs_paths=trajs_path,
            model_path=model_path,
            num_training_envs=num_training_envs,
            teacher=teacher,
            causal_features_encoder=causal_features_encoder,
            noise_features_encoders=noise_features_encoders,
            causal_features_decoder=causal_features_decoder,
            noise_features_decoders=noise_features_decoders,
            observations_decoder=observations_decoder,
            env_discriminator=env_discriminator,
            policy_network=policy_network,
            energy_model=energy_model,
            mine_network=mine_network,
            buffer=buffer,
            adam_alpha=config["ADAM_ALPHA"],
            config = config
        )


def init_arg():
    parser = argparse.ArgumentParser()
    parser.add_argument("--env_name", default="CartPole-v1")
    parser.add_argument("--num_trajectories", default=20, type=int)
    parser.add_argument("--trial", default=0, type=int)
    return parser.parse_args()

# %% [markdown]
# #10 Trails -- BCIRM

# %%
config['METHOD'] = "BCIRM"

for traj_num in [2, 4, 8, 16, 32, 64, 128]:
    config["NUM_TRAJS_GIVEN"] = traj_num
    config["TRAJ_SHIFT"] = traj_num

    config['ALG'] = "FINAL_BCIRMStudent_replicatedata_trajnum" + str(traj_num)


    ###############.  settings   ###############
    #config['ALG'] = "BCIRMStudent_Apr19_replicatedata"
    #config['METHOD'] = "BCIRM"
    #config['METHOD'] = "ICIL"
    #config["NUM_TRAJS_GIVEN"] = 50
    #config["TRAJ_SHIFT"] = 50
    #config['ENV'] == "CartPole-v1"
    ###############.  settings   ###############


    if config['METHOD'] == 'BCIRM':
        config['l2_regularizer_weight'] = 0.001
        config['penalty_weight'] = 10000
        config['penalty_anneal_iters'] = 5000

    all_results_trail = []

    for trail in range(1): 
        config['TRIAL'] = trail 


        ###############.  start a trail   ###############

        config["EXPERT_ALG"] = yaml.load(open("testing/config.yml"), Loader=yaml.FullLoader)[config["ENV"]]
        print("Config: %s" % config)

        TRIAL = config["TRIAL"] #args.trial
        print("Trial number %s" % TRIAL)

        results_dir_base = "testing/results/"
        results_dir = os.path.join(results_dir_base, config["ENV"], str(config["NUM_TRAJS_GIVEN"]), config["ALG"])

        if not os.path.exists(results_dir):
            os.makedirs(results_dir)

        config_file = "trial_" + str(TRIAL) + "_" + "config.pkl"

        results_file_name = "trial_" + str(TRIAL) + "_" + "results.csv"
        results_file_path = os.path.join(results_dir, results_file_name)

        if os.path.exists(os.path.join(results_dir, config_file)):
            raise NameError("CONFIG file already exists %s. Choose a different trial number." % config_file)
        pickle.dump(config, open(os.path.join(results_dir, config_file), "wb"))




        ###############.  10 runs for each trail   ###############

        print("config method = ", config['METHOD'])
        print("config env = ", config['ENV'])

        for run_seed in range(config["NUM_REPETITIONS"]):
            print("Run %s out of %s" % (run_seed + 1, config["NUM_REPETITIONS"]))
            student = make_student(run_seed, config)
            student.train(num_updates=config["NUM_STEPS_TRAIN"])

            env_wrapper_out_of_sample = EnvWrapper(
                env=gym.make(config["ENV"]), mult_factor=get_test_mult_factors(config['NOISE_DIM'] - 1), idx=3, seed=1
            )

            env_wrapper_out_of_sample.noise = 0

            action_match, return_mean, return_std = student.test(
                num_episodes=config["NUM_TRAJS_VALID"], env_wrapper=env_wrapper_out_of_sample
            )

            result = (action_match, return_mean, return_std)
            print("###############    Reward for test environment for run %s: %s.   ###############\n\n" % (run_seed + 1, return_mean))
            save_results(results_file_path, run_seed, action_match, return_mean, return_std)

        results_trial = pd.read_csv(
            "testing/results/"
            + config["ENV"]
            + "/"
            + str(config["NUM_TRAJS_GIVEN"])
            + "/"
            + config["ALG"]
            + "/trial_"
            + str(TRIAL)
            + "_results.csv",
            header=None,
        )

        print("Average reward for 10 repetitions: %s" % np.mean(results_trial[2].values))

        all_results_trail.append(np.mean(results_trial[2].values))
    print("ALL RESULTS TRAIL:" , all_results_trail)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 8400 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 15: -110.50911553111006.   ###############
#
#
# Average reward for 10 repetitions: -258.62343578818223
# ALL RESULTS TRAIL: [-258.62343578818223]
# Config: {'ENV': 'LunarLander-v2', 'ALG': 'FINAL_BCIRMStudent_replicatedata_trajnum4', 'NUM_TRAJS_GIVEN': 4, 'NUM_TRAINING_ENVS': 2, 'NOISE_DIM': 4, 'REP_SIZE': 16, 'TRAJ_SHIFT': 4, 'SAMPLING_RATE': 5, 'NUM_STEPS_TRAIN': 10000, 'NUM_TRAJS_VALID': 100, 'NUM_REPETITIONS': 15, 'BATCH_SIZE': 64, 'MLP_WIDTHS': 64, 'ADAM_ALPHA': 0.001, 'SGLD_BUFFER_SIZE': 10000, 'SGLD_LEARN_RATE': 0.01, 'SGLD_NOISE_COEF': 0.01, 'SGLD_NUM_STEPS': 100, 'SGLD_REINIT_FREQ': 0.05, 'NUM_STEPS_TRAIN_ENERGY_MODEL': 1000, 'TRIAL': 0, 'METHOD': 'BCIRM', 'l2_regularizer_weight': 0.001, 'penalty_weight': 10000, 'penalty_anneal_iters': 5000, 'EXPERT_ALG': 'dqn'}
# Trial number 0
# config method =  BCIRM
# config env =  LunarLander-v2
# Run 1 out of 15
# state_dim 12
# 200 tensor(0.7034, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.6857, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.6806, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.5853, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.5743, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.5935, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.6078, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.5334, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.4200, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.4825, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.5169, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.5251, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.4887, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.3705, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.4770, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.5367, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.4991, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.5375, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.5159, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4285, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.3488, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.3455, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.5138, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.3443, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0147, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0286, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0217, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0089, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0064, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0045, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0092, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0088, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0076, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 1: -352.95903026957063.   ###############
#
#
# Run 2 out of 15
# state_dim 12
# 200 tensor(0.9783, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.9616, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.8792, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.7945, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.7098, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.5524, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.4909, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.5855, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.5915, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.5986, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.6092, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.4676, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.6723, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.4919, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.4095, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.4472, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.3587, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.4467, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.4875, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.3678, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.3161, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4147, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.4106, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4425, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0137, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0135, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0156, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0175, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 2: -260.2820409328257.   ###############
#
#
# Run 3 out of 15
# state_dim 12
# 200 tensor(0.8754, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.7261, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.9152, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.7163, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.7552, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.6051, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.6445, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.7272, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.6994, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.5258, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.5639, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.6216, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.6660, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.6183, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.5781, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.6235, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.4609, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.4721, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.5425, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.6284, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.4684, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.6180, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.4886, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.5569, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0069, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0135, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0097, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0086, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0174, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0081, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 3: 12.61388300026625.   ###############
#
#
# Run 4 out of 15
# state_dim 12
# 200 tensor(0.8139, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.9174, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.5929, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.8620, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.5411, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.5776, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.6230, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.4846, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.4974, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.5540, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.5505, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.5081, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.5199, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.3645, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.5731, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.4137, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.5853, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.5411, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.4258, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.5516, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.4062, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4958, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.4186, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4394, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0061, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0055, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0094, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0074, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 4: -72.3790727932736.   ###############
#
#
# Run 5 out of 15
# state_dim 12
# 200 tensor(0.8999, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.9341, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.8031, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.8849, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.6384, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.6719, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.5731, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.7294, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.5253, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.6347, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.4702, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.5012, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.5151, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.5863, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.5109, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.5792, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.4794, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.4941, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.5048, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4699, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.4645, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4354, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.4243, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4330, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0061, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 5: -70.81700890789949.   ###############
#
#
# Run 6 out of 15
# state_dim 12
# 200 tensor(1.1191, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.8468, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.8196, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.8033, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.8303, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.6491, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.6257, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.6109, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.6235, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.7576, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.6671, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.5969, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.6689, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.5848, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.6144, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.4926, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.5778, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.5776, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.6456, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.5183, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.3664, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.5293, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.4807, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4589, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0122, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0083, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0056, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0049, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0436, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0239, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 6: -92.02276850976276.   ###############
#
#
# Run 7 out of 15
# state_dim 12
# 200 tensor(0.8809, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.9800, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.8396, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.8625, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.6524, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.5270, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.6684, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.5994, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.6085, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.7660, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.4281, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.6116, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.4839, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.4906, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.5877, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.5739, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.5428, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.6110, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.5214, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.5162, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.5704, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4646, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.5774, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4630, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0060, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0038, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0106, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0179, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0288, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0163, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0854, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0060, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0107, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0080, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0016, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0065, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 7: -297.9777838847124.   ###############
#
#
# Run 8 out of 15
# state_dim 12
# 200 tensor(0.8812, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.8046, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.9185, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.7982, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(1.0118, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.7658, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.7795, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.7891, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.7114, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.9948, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.6591, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.7490, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.6677, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.6530, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.5978, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.6367, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.6260, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.6098, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.7117, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.6369, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.7793, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.7647, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.7847, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.6135, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0080, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0095, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0190, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0056, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0077, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0047, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0122, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 8: -381.2685565186702.   ###############
#
#
# Run 9 out of 15
# state_dim 12
# 200 tensor(1.0005, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.9463, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(1.0249, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.8954, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.7839, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.5644, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.8337, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.7090, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.6157, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.6588, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.6516, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.6880, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.6336, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.8822, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.6344, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.6452, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.6025, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.5766, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.8628, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.7827, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.7385, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.6820, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.5292, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.7079, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0165, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0102, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0142, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0185, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0146, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 9: -209.61199974678163.   ###############
#
#
# Run 10 out of 15
# state_dim 12
# 200 tensor(1.1790, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(1.0187, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.9672, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(1.0946, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.9293, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.9308, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(1.0695, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.9504, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.8593, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.7710, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.7345, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.8377, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.8233, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.8500, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.7277, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.7485, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.6909, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.6247, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.6314, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.7114, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.6328, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4305, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.5489, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.6396, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0207, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0096, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0117, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0037, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0156, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0068, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0043, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 10: -300.1349324181004.   ###############
#
#
# Run 11 out of 15
# state_dim 12
# 200 tensor(0.8201, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.9121, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.5557, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.8364, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.6481, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.7543, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.9047, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.6186, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.6703, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.6777, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.7396, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.6748, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.5860, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.5054, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.4898, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.5615, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.5498, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.5605, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.5021, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4479, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.5161, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.5033, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.5017, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4674, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0071, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0063, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0027, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0109, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0183, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(8.7226e-05, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0049, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 11: -142.65036289420155.   ###############
#
#
# Run 12 out of 15
# state_dim 12
# 200 tensor(0.8772, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.8910, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.9334, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(1.0247, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.8739, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.6703, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.6391, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.6254, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.5862, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.6317, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.6317, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.5164, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.8526, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.5970, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.5904, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.5672, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.6694, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.6738, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.6009, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4471, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.4841, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.6853, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.6222, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.5662, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0187, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0118, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0057, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0025, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0049, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0088, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.3059, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0059, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 12: -270.4646750765815.   ###############
#
#
# Run 13 out of 15
# state_dim 12
# 200 tensor(0.9604, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.6401, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.7337, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.6807, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.6724, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.7619, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.8107, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.6936, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.6177, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.8252, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.6227, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.6443, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.6347, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.7032, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.6447, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.6740, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.6885, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.6154, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.6848, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.5868, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.6877, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.6655, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.6914, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.5542, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0045, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0087, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0120, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0169, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0056, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0033, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0077, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0050, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 13: -23.643345449509233.   ###############
#
#
# Run 14 out of 15
# state_dim 12
# 200 tensor(0.9524, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.7101, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.6244, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.7596, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.5940, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.6932, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.6010, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.6643, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.6002, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.5629, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.4188, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.4705, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.4894, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.4015, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.4434, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.4942, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.5164, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.4715, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.3771, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4354, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.3533, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.3791, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.3547, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.3390, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0056, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0054, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0123, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0173, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0360, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0102, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0055, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0056, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0055, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0124, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0063, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0085, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0643, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0070, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0093, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0219, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0001, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 14: 26.311292470395482.   ###############
#
#
# Run 15 out of 15
# state_dim 12
# 200 tensor(0.9864, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.7437, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.7491, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.7513, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.8259, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.6435, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.6650, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.5943, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.5407, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.6403, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.5769, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.5666, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.7741, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.5031, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.4268, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.6799, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.4335, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.5883, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.5206, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.5192, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.4309, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4346, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.4893, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.3208, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0052, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0073, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
# ...
#
#
# Run 11 out of 15
# state_dim 12
# 200 tensor(0.9631, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(1.0988, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.9255, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.8684, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.7759, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(1.0651, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.8954, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.8995, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.8628, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.8525, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.9160, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(1.0166, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.8566, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.8745, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.9377, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.7980, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.7529, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.8510, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.7734, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.8273, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.8474, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.9775, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.6792, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.8368, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0182, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0076, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0141, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0031, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0045, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0063, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0020, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 11: -764.8863282736403.   ###############
#
#
# Run 12 out of 15
# state_dim 12
# 200 tensor(0.8917, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(1.2272, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(1.1274, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(1.0592, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.9469, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.8083, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(1.2630, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.9470, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.9333, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.9381, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.9803, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.9270, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(1.0116, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.8845, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.9440, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.9953, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.9390, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.7997, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.7529, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.7995, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(1.0831, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.7408, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.9825, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.9844, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0193, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0125, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0076, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0030, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0040, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0105, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0032, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0066, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0064, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0011, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0059, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0041, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0012, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 12: -272.020453138548.   ###############
#
#
# Run 13 out of 15
# state_dim 12
# 200 tensor(1.0761, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(1.0570, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.9183, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(1.2280, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(1.0114, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.8510, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.8943, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.7561, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.9917, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.8508, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.9122, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.9630, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.8251, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.8745, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.9363, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.8364, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.7034, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.8316, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(1.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.8607, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.8940, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.7435, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.9054, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.9589, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0248, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0018, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0034, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0093, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0081, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0002, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 13: -944.157300123618.   ###############
#
#
# Run 14 out of 15
# state_dim 12
# 200 tensor(1.1253, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(1.0490, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(1.0875, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(1.1090, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.8912, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.8691, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(1.1101, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.9235, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.8634, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(1.1303, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.9946, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.9779, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.9068, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.8543, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.7740, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.9600, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.7890, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.7796, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.8568, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.8185, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.7058, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.8965, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.7945, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.7043, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0021, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0472, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0221, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0073, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0413, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0042, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0026, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0036, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0093, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0022, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0126, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0113, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0014, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0085, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0029, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0071, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0010, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0024, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 14: -608.2199648083658.   ###############
#
#
# Run 15 out of 15
# state_dim 12
# 200 tensor(1.0789, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.9445, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(1.1449, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(1.1216, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(1.0354, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.9308, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(1.0412, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.9022, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.9835, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.8511, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.8078, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.9051, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.8446, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.8979, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.9188, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.8862, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.8489, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.9672, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.9510, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.8030, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.6410, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.7586, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.7094, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.7207, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.0308, device='cuda:0', grad_fn=<DivBackward0>)
# 5200 tensor(0.0102, device='cuda:0', grad_fn=<DivBackward0>)
# 5400 tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
# 5600 tensor(0.0017, device='cuda:0', grad_fn=<DivBackward0>)
# 5800 tensor(0.0023, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(0.0053, device='cuda:0', grad_fn=<DivBackward0>)
# 6200 tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
# 6400 tensor(0.0096, device='cuda:0', grad_fn=<DivBackward0>)
# 6600 tensor(0.0062, device='cuda:0', grad_fn=<DivBackward0>)
# 6800 tensor(0.0058, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(0.0116, device='cuda:0', grad_fn=<DivBackward0>)
# 7200 tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# 7400 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 7600 tensor(0.0015, device='cuda:0', grad_fn=<DivBackward0>)
# 7800 tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>)
# 8200 tensor(0.0035, device='cuda:0', grad_fn=<DivBackward0>)
# 8400 tensor(0.0003, device='cuda:0', grad_fn=<DivBackward0>)
# 8600 tensor(0.0019, device='cuda:0', grad_fn=<DivBackward0>)
# 8800 tensor(0.0028, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(0.0051, device='cuda:0', grad_fn=<DivBackward0>)
# 9200 tensor(0.0008, device='cuda:0', grad_fn=<DivBackward0>)
# 9400 tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>)
# 9600 tensor(0.0013, device='cuda:0', grad_fn=<DivBackward0>)
# 9800 tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(0.0039, device='cuda:0', grad_fn=<DivBackward0>)
# ###############    Reward for test environment for run 15: -273.481806773641.   ###############
#
#
# Average reward for 10 repetitions: -630.149566414595
# ALL RESULTS TRAIL: [-630.149566414595]

# %% [markdown]
# #10 Trails -- BC

# %%
config['METHOD'] = "BC"

for traj_num in [2, 4, 8, 16, 32, 64, 128]:
    config["NUM_TRAJS_GIVEN"] = traj_num
    config["TRAJ_SHIFT"] = traj_num


    config['ALG'] = "FINAL_BCStudent_replicatedata_trajnum" + str(traj_num)


    ###############.  settings   ###############
    #config['ALG'] = "BCStudent_Apr19_replicatedata"
    #config['METHOD'] = "BC"
    #config['ENV'] == "CartPole-v1"
    #config['ENV'] == "LunarLander-v2"
    #config["NUM_TRAJS_GIVEN"] = 20
    #config["TRAJ_SHIFT"] = 20
    ###############.  settings   ###############



    if config['METHOD'] == 'BCIRM':
        config['l2_regularizer_weight'] = 0.001
        config['penalty_weight'] = 10000
        config['penalty_anneal_iters'] = 100

    all_results_trail = []

    for trail in range(1): 
        config['TRIAL'] = trail 


        ###############.  start a trail   ###############

        config["EXPERT_ALG"] = yaml.load(open("testing/config.yml"), Loader=yaml.FullLoader)[config["ENV"]]
        print("Config: %s" % config)

        TRIAL = config["TRIAL"] #args.trial
        print("Trial number %s" % TRIAL)

        results_dir_base = "testing/results/"
        results_dir = os.path.join(results_dir_base, config["ENV"], str(config["NUM_TRAJS_GIVEN"]), config["ALG"])

        if not os.path.exists(results_dir):
            os.makedirs(results_dir)

        config_file = "trial_" + str(TRIAL) + "_" + "config.pkl"

        results_file_name = "trial_" + str(TRIAL) + "_" + "results.csv"
        results_file_path = os.path.join(results_dir, results_file_name)

        if os.path.exists(os.path.join(results_dir, config_file)):
            raise NameError("CONFIG file already exists %s. Choose a different trial number." % config_file)
        pickle.dump(config, open(os.path.join(results_dir, config_file), "wb"))




        ###############.  10 runs for each trail   ###############

        print("config method = ", config['METHOD'])
        print("config env = ", config['ENV'])

        for run_seed in range(config["NUM_REPETITIONS"]):
            print("Run %s out of %s" % (run_seed + 1, config["NUM_REPETITIONS"]))
            student = make_student(run_seed, config)
            student.train(num_updates=config["NUM_STEPS_TRAIN"])

            env_wrapper_out_of_sample = EnvWrapper(
                env=gym.make(config["ENV"]), mult_factor=get_test_mult_factors(config['NOISE_DIM'] - 1), idx=3, seed=1
            )
            action_match, return_mean, return_std = student.test(
                num_episodes=config["NUM_TRAJS_VALID"], env_wrapper=env_wrapper_out_of_sample
            )

            result = (action_match, return_mean, return_std)
            print("###############    Reward for test environment for run %s: %s.   ###############\n\n" % (run_seed + 1, return_mean))
            save_results(results_file_path, run_seed, action_match, return_mean, return_std)

        results_trial = pd.read_csv(
            "testing/results/"
            + config["ENV"]
            + "/"
            + str(config["NUM_TRAJS_GIVEN"])
            + "/"
            + config["ALG"]
            + "/trial_"
            + str(TRIAL)
            + "_results.csv",
            header=None,
        )

        print("Average reward for 10 repetitions: %s" % np.mean(results_trial[2].values))

        all_results_trail.append(np.mean(results_trial[2].values))

    print("ALL RESULTS TRAIL:" , all_results_trail)
# Out:
# Config: {'ENV': 'LunarLander-v2', 'ALG': 'FINAL_BCStudent_replicatedata_trajnum2', 'NUM_TRAJS_GIVEN': 2, 'NUM_TRAINING_ENVS': 2, 'NOISE_DIM': 4, 'REP_SIZE': 16, 'TRAJ_SHIFT': 2, 'SAMPLING_RATE': 5, 'NUM_STEPS_TRAIN': 10000, 'NUM_TRAJS_VALID': 100, 'NUM_REPETITIONS': 15, 'BATCH_SIZE': 64, 'MLP_WIDTHS': 64, 'ADAM_ALPHA': 0.001, 'SGLD_BUFFER_SIZE': 10000, 'SGLD_LEARN_RATE': 0.01, 'SGLD_NOISE_COEF': 0.01, 'SGLD_NUM_STEPS': 100, 'SGLD_REINIT_FREQ': 0.05, 'NUM_STEPS_TRAIN_ENERGY_MODEL': 1000, 'TRIAL': 0, 'METHOD': 'BC', 'l2_regularizer_weight': 0.001, 'penalty_weight': 10000, 'penalty_anneal_iters': 5000, 'EXPERT_ALG': 'dqn'}
# Trial number 0
# config method =  BC
# config env =  LunarLander-v2
# Run 1 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 1: -49.63886930878617.   ###############
#
#
# Run 2 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 2: -421.42129691333395.   ###############
#
#
# Run 3 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 3: -452.3824655003357.   ###############
#
#
# Run 4 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 4: -227.66562686023192.   ###############
#
#
# Run 5 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 5: -32.988951968571115.   ###############
#
#
# Run 6 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 6: 73.98168910665603.   ###############
#
#
# Run 7 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 7: -40.14999536440053.   ###############
#
#
# Run 8 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 8: -415.21704203155196.   ###############
#
#
# Run 9 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 9: -279.43934129562126.   ###############
#
#
# Run 10 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 10: -483.7608966547793.   ###############
#
#
# Run 11 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 11: -388.36416750370677.   ###############
#
#
# Run 12 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 12: -175.94295667221868.   ###############
#
#
# Run 13 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 13: -487.13412599884674.   ###############
#
#
# Run 14 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 14: -137.13078385988373.   ###############
#
#
# Run 15 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 15: -214.02646978478134.   ###############
#
#
# Average reward for 10 repetitions: -248.75208670735955
# ALL RESULTS TRAIL: [-248.75208670735955]
# Config: {'ENV': 'LunarLander-v2', 'ALG': 'FINAL_BCStudent_replicatedata_trajnum4', 'NUM_TRAJS_GIVEN': 4, 'NUM_TRAINING_ENVS': 2, 'NOISE_DIM': 4, 'REP_SIZE': 16, 'TRAJ_SHIFT': 4, 'SAMPLING_RATE': 5, 'NUM_STEPS_TRAIN': 10000, 'NUM_TRAJS_VALID': 100, 'NUM_REPETITIONS': 15, 'BATCH_SIZE': 64, 'MLP_WIDTHS': 64, 'ADAM_ALPHA': 0.001, 'SGLD_BUFFER_SIZE': 10000, 'SGLD_LEARN_RATE': 0.01, 'SGLD_NOISE_COEF': 0.01, 'SGLD_NUM_STEPS': 100, 'SGLD_REINIT_FREQ': 0.05, 'NUM_STEPS_TRAIN_ENERGY_MODEL': 1000, 'TRIAL': 0, 'METHOD': 'BC', 'l2_regularizer_weight': 0.001, 'penalty_weight': 10000, 'penalty_anneal_iters': 5000, 'EXPERT_ALG': 'dqn'}
# Trial number 0
# config method =  BC
# config env =  LunarLander-v2
# Run 1 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 1: -238.70683316486452.   ###############
#
#
# Run 2 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 2: -411.6952195302781.   ###############
#
#
# Run 3 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 3: 125.23926934275994.   ###############
#
#
# Run 4 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 4: 39.068795979801756.   ###############
#
#
# Run 5 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 5: -170.29409685856487.   ###############
#
#
# Run 6 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 6: -36.923397708220136.   ###############
#
#
# Run 7 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 7: 3.643692466496401.   ###############
#
#
# Run 8 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 8: -131.7248165499371.   ###############
#
#
# Run 9 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 9: 19.118571732708823.   ###############
#
#
# Run 10 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 10: 75.53815232725952.   ###############
#
#
# Run 11 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 11: -280.49170659118755.   ###############
#
#
# Run 12 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 12: -8.688374489199532.   ###############
#
#
# Run 13 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 13: 13.151374022474247.   ###############
#
#
# Run 14 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 14: 58.8682827214802.   ###############
#
#
# Run 15 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 15: 110.85238957294158.   ###############
#
#
# Average reward for 10 repetitions: -55.536261115088635
# ALL RESULTS TRAIL: [-55.536261115088635]
# Config: {'ENV': 'LunarLander-v2', 'ALG': 'FINAL_BCStudent_replicatedata_trajnum8', 'NUM_TRAJS_GIVEN': 8, 'NUM_TRAINING_ENVS': 2, 'NOISE_DIM': 4, 'REP_SIZE': 16, 'TRAJ_SHIFT': 8, 'SAMPLING_RATE': 5, 'NUM_STEPS_TRAIN': 10000, 'NUM_TRAJS_VALID': 100, 'NUM_REPETITIONS': 15, 'BATCH_SIZE': 64, 'MLP_WIDTHS': 64, 'ADAM_ALPHA': 0.001, 'SGLD_BUFFER_SIZE': 10000, 'SGLD_LEARN_RATE': 0.01, 'SGLD_NOISE_COEF': 0.01, 'SGLD_NUM_STEPS': 100, 'SGLD_REINIT_FREQ': 0.05, 'NUM_STEPS_TRAIN_ENERGY_MODEL': 1000, 'TRIAL': 0, 'METHOD': 'BC', 'l2_regularizer_weight': 0.001, 'penalty_weight': 10000, 'penalty_anneal_iters': 5000, 'EXPERT_ALG': 'dqn'}
# Trial number 0
# config method =  BC
# config env =  LunarLander-v2
# Run 1 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 1: -40.70213936095511.   ###############
#
#
# Run 2 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 2: -416.9401515330772.   ###############
#
#
# Run 3 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 3: 95.5148781725636.   ###############
#
#
# Run 4 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 4: 167.21560004704847.   ###############
#
#
# Run 5 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 5: 3.448781968966212.   ###############
#
#
# Run 6 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 6: 57.66577697841729.   ###############
#
#
# Run 7 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 7: -135.57582720941855.   ###############
#
#
# Run 8 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 8: 199.38277759344382.   ###############
#
#
# Run 9 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 9: -139.50901812805887.   ###############
#
#
# Run 10 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 10: 47.624330263913045.   ###############
#
#
# Run 11 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 11: 143.24241846407986.   ###############
#
#
# Run 12 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 12: -183.1821817206024.   ###############
#
#
# Run 13 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 13: -222.87546922225877.   ###############
#
#
# Run 14 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 14: 188.75489433837853.   ###############
#
#
# Run 15 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 15: -259.30417509900445.   ###############
#
#
# Average reward for 10 repetitions: -33.015966963104304
# ALL RESULTS TRAIL: [-33.015966963104304]
# Config: {'ENV': 'LunarLander-v2', 'ALG': 'FINAL_BCStudent_replicatedata_trajnum16', 'NUM_TRAJS_GIVEN': 16, 'NUM_TRAINING_ENVS': 2, 'NOISE_DIM': 4, 'REP_SIZE': 16, 'TRAJ_SHIFT': 16, 'SAMPLING_RATE': 5, 'NUM_STEPS_TRAIN': 10000, 'NUM_TRAJS_VALID': 100, 'NUM_REPETITIONS': 15, 'BATCH_SIZE': 64, 'MLP_WIDTHS': 64, 'ADAM_ALPHA': 0.001, 'SGLD_BUFFER_SIZE': 10000, 'SGLD_LEARN_RATE': 0.01, 'SGLD_NOISE_COEF': 0.01, 'SGLD_NUM_STEPS': 100, 'SGLD_REINIT_FREQ': 0.05, 'NUM_STEPS_TRAIN_ENERGY_MODEL': 1000, 'TRIAL': 0, 'METHOD': 'BC', 'l2_regularizer_weight': 0.001, 'penalty_weight': 10000, 'penalty_anneal_iters': 5000, 'EXPERT_ALG': 'dqn'}
# Trial number 0
# config method =  BC
# config env =  LunarLander-v2
# Run 1 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 1: 186.9993555437649.   ###############
#
#
# Run 2 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 2: -27.54804187111345.   ###############
#
#
# Run 3 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 3: 45.72340429671411.   ###############
#
#
# Run 4 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 4: -56.358208769867396.   ###############
#
#
# Run 5 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 5: 207.5838571877131.   ###############
#
#
# Run 6 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 6: 11.338445708885201.   ###############
#
#
# Run 7 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 7: 183.04061522687272.   ###############
#
#
# Run 8 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 8: 158.43877198293293.   ###############
#
#
# Run 9 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 9: 173.72658822314182.   ###############
#
#
# Run 10 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 10: -21.017795176420876.   ###############
#
#
# Run 11 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 11: 155.0980876367919.   ###############
#
#
# Run 12 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 12: 177.59680425606413.   ###############
#
#
# Run 13 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 13: 183.7894487063185.   ###############
#
#
# Run 14 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 14: 128.9819533053787.   ###############
#
#
# Run 15 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 15: 199.88608937061923.   ###############
#
#
# Average reward for 10 repetitions: 113.81862504185302
# ALL RESULTS TRAIL: [113.81862504185302]
# Config: {'ENV': 'LunarLander-v2', 'ALG': 'FINAL_BCStudent_replicatedata_trajnum32', 'NUM_TRAJS_GIVEN': 32, 'NUM_TRAINING_ENVS': 2, 'NOISE_DIM': 4, 'REP_SIZE': 16, 'TRAJ_SHIFT': 32, 'SAMPLING_RATE': 5, 'NUM_STEPS_TRAIN': 10000, 'NUM_TRAJS_VALID': 100, 'NUM_REPETITIONS': 15, 'BATCH_SIZE': 64, 'MLP_WIDTHS': 64, 'ADAM_ALPHA': 0.001, 'SGLD_BUFFER_SIZE': 10000, 'SGLD_LEARN_RATE': 0.01, 'SGLD_NOISE_COEF': 0.01, 'SGLD_NUM_STEPS': 100, 'SGLD_REINIT_FREQ': 0.05, 'NUM_STEPS_TRAIN_ENERGY_MODEL': 1000, 'TRIAL': 0, 'METHOD': 'BC', 'l2_regularizer_weight': 0.001, 'penalty_weight': 10000, 'penalty_anneal_iters': 5000, 'EXPERT_ALG': 'dqn'}
# Trial number 0
# config method =  BC
# config env =  LunarLander-v2
# Run 1 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 1: 132.90709716313296.   ###############
#
#
# Run 2 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 2: 237.26417502249677.   ###############
#
#
# Run 3 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 3: 203.6183964742919.   ###############
#
#
# Run 4 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 4: 210.91409354228009.   ###############
#
#
# Run 5 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 5: 212.33490121272203.   ###############
#
#
# Run 6 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 6: 190.83971170295027.   ###############
#
#
# Run 7 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 7: 229.01405166852845.   ###############
#
#
# Run 8 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 8: 205.89983727921094.   ###############
#
#
# Run 9 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 9: 103.78349618547423.   ###############
#
#
# Run 10 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 10: 142.92420365728512.   ###############
#
#
# Run 11 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 11: 102.39579830013552.   ###############
#
#
# Run 12 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 12: 221.9755642694636.   ###############
#
#
# Run 13 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 13: 210.7346521123305.   ###############
#
#
# Run 14 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 14: 246.54073018913758.   ###############
#
#
# Run 15 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 15: 210.87825270504504.   ###############
#
#
# Average reward for 10 repetitions: 190.80166409896566
# ALL RESULTS TRAIL: [190.80166409896566]
# Config: {'ENV': 'LunarLander-v2', 'ALG': 'FINAL_BCStudent_replicatedata_trajnum64', 'NUM_TRAJS_GIVEN': 64, 'NUM_TRAINING_ENVS': 2, 'NOISE_DIM': 4, 'REP_SIZE': 16, 'TRAJ_SHIFT': 64, 'SAMPLING_RATE': 5, 'NUM_STEPS_TRAIN': 10000, 'NUM_TRAJS_VALID': 100, 'NUM_REPETITIONS': 15, 'BATCH_SIZE': 64, 'MLP_WIDTHS': 64, 'ADAM_ALPHA': 0.001, 'SGLD_BUFFER_SIZE': 10000, 'SGLD_LEARN_RATE': 0.01, 'SGLD_NOISE_COEF': 0.01, 'SGLD_NUM_STEPS': 100, 'SGLD_REINIT_FREQ': 0.05, 'NUM_STEPS_TRAIN_ENERGY_MODEL': 1000, 'TRIAL': 0, 'METHOD': 'BC', 'l2_regularizer_weight': 0.001, 'penalty_weight': 10000, 'penalty_anneal_iters': 5000, 'EXPERT_ALG': 'dqn'}
# Trial number 0
# config method =  BC
# config env =  LunarLander-v2
# Run 1 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 1: 190.21513320748636.   ###############
#
#
# Run 2 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 2: 239.2262868854375.   ###############
#
#
# Run 3 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 3: 96.52050106983077.   ###############
#
#
# Run 4 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 4: 218.69129252535586.   ###############
#
#
# Run 5 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 5: 122.65669337457632.   ###############
#
#
# Run 6 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 6: 232.89481661789767.   ###############
#
#
# Run 7 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 7: 219.57449370013583.   ###############
#
#
# Run 8 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 8: 122.07371795544414.   ###############
#
#
# Run 9 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 9: 187.88475587531045.   ###############
#
#
# Run 10 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 10: 187.94133738698054.   ###############
#
#
# Run 11 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 11: 241.83484703806764.   ###############
#
#
# Run 12 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 12: 110.56531230495338.   ###############
#
#
# Run 13 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 13: 199.05316912950562.   ###############
#
#
# Run 14 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 14: 229.29506725149793.   ###############
#
#
# Run 15 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 15: 185.96892126846117.   ###############
#
#
# Average reward for 10 repetitions: 185.6264230393961
# ALL RESULTS TRAIL: [185.6264230393961]
# Config: {'ENV': 'LunarLander-v2', 'ALG': 'FINAL_BCStudent_replicatedata_trajnum128', 'NUM_TRAJS_GIVEN': 128, 'NUM_TRAINING_ENVS': 2, 'NOISE_DIM': 4, 'REP_SIZE': 16, 'TRAJ_SHIFT': 128, 'SAMPLING_RATE': 5, 'NUM_STEPS_TRAIN': 10000, 'NUM_TRAJS_VALID': 100, 'NUM_REPETITIONS': 15, 'BATCH_SIZE': 64, 'MLP_WIDTHS': 64, 'ADAM_ALPHA': 0.001, 'SGLD_BUFFER_SIZE': 10000, 'SGLD_LEARN_RATE': 0.01, 'SGLD_NOISE_COEF': 0.01, 'SGLD_NUM_STEPS': 100, 'SGLD_REINIT_FREQ': 0.05, 'NUM_STEPS_TRAIN_ENERGY_MODEL': 1000, 'TRIAL': 0, 'METHOD': 'BC', 'l2_regularizer_weight': 0.001, 'penalty_weight': 10000, 'penalty_anneal_iters': 5000, 'EXPERT_ALG': 'dqn'}
# Trial number 0
# config method =  BC
# config env =  LunarLander-v2
# Run 1 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 1: 110.909525701449.   ###############
#
#
# Run 2 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 2: 199.5690195590528.   ###############
#
#
# Run 3 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 3: 28.7021829465504.   ###############
#
#
# Run 4 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 4: 247.52669697893853.   ###############
#
#
# Run 5 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 5: 245.91544747179614.   ###############
#
#
# Run 6 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 6: 54.47641123216058.   ###############
#
#
# Run 7 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 7: 166.17364737265726.   ###############
#
#
# Run 8 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 8: 156.38991623494474.   ###############
#
#
# Run 9 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 9: 100.17091381708173.   ###############
#
#
# Run 10 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 10: 230.93607331405127.   ###############
#
#
# Run 11 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 11: 177.83872995447956.   ###############
#
#
# Run 12 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 12: 168.1566964452229.   ###############
#
#
# Run 13 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 13: 82.73442324153568.   ###############
#
#
# Run 14 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 14: 241.30349183584713.   ###############
#
#
# Run 15 out of 15
# state_dim 12
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 15: 225.38304297107373.   ###############
#
#
# Average reward for 10 repetitions: 162.41241460512276
# ALL RESULTS TRAIL: [162.41241460512276]

# %% [markdown]
# #10 Trails -- ICIL

# %%
config['METHOD'] = "ICIL"

for traj_num in [2, 4, 8, 16, 32, 64, 128]:
    config["NUM_TRAJS_GIVEN"] = traj_num
    config["TRAJ_SHIFT"] = traj_num


    config['ALG'] = "FINAL_ICILStudent_replicatedata_trajnum2" + str(traj_num)


    ###############.  settings   ###############
    #config['ALG'] = "ICILStudent_Apr19_replicatedata"
    #config['METHOD'] = "ICIL"
    #config['ENV'] == "CartPole-v1"
    #config['ENV'] == "LunarLander-v2"

    ###############.  settings   ###############



    if config['METHOD'] == 'BCIRM':
        config['l2_regularizer_weight'] = 0.001
        config['penalty_weight'] = 10000
        config['penalty_anneal_iters'] = 100

    all_results_trail = []

    for trail in range(1): 
        config['TRIAL'] = trail 


        ###############.  start a trail   ###############

        config["EXPERT_ALG"] = yaml.load(open("testing/config.yml"), Loader=yaml.FullLoader)[config["ENV"]]
        print("Config: %s" % config)

        TRIAL = config["TRIAL"] #args.trial
        print("Trial number %s" % TRIAL)

        results_dir_base = "testing/results/"
        results_dir = os.path.join(results_dir_base, config["ENV"], str(config["NUM_TRAJS_GIVEN"]), config["ALG"])

        if not os.path.exists(results_dir):
            os.makedirs(results_dir)

        config_file = "trial_" + str(TRIAL) + "_" + "config.pkl"

        results_file_name = "trial_" + str(TRIAL) + "_" + "results.csv"
        results_file_path = os.path.join(results_dir, results_file_name)

        if os.path.exists(os.path.join(results_dir, config_file)):
            raise NameError("CONFIG file already exists %s. Choose a different trial number." % config_file)
        pickle.dump(config, open(os.path.join(results_dir, config_file), "wb"))




        ###############.  10 runs for each trail   ###############

        print("config method = ", config['METHOD'])
        print("config env = ", config['ENV'])

        for run_seed in range(config["NUM_REPETITIONS"]):
            print("Run %s out of %s" % (run_seed + 1, config["NUM_REPETITIONS"]))
            student = make_student(run_seed, config)
            student.train(num_updates=config["NUM_STEPS_TRAIN"])

            env_wrapper_out_of_sample = EnvWrapper(
                env=gym.make(config["ENV"]), mult_factor=get_test_mult_factors(config['NOISE_DIM'] - 1), idx=3, seed=1
            )
            action_match, return_mean, return_std = student.test(
                num_episodes=config["NUM_TRAJS_VALID"], env_wrapper=env_wrapper_out_of_sample
            )

            result = (action_match, return_mean, return_std)
            print("###############    Reward for test environment for run %s: %s.   ###############\n\n" % (run_seed + 1, return_mean))
            save_results(results_file_path, run_seed, action_match, return_mean, return_std)

        results_trial = pd.read_csv(
            "testing/results/"
            + config["ENV"]
            + "/"
            + str(config["NUM_TRAJS_GIVEN"])
            + "/"
            + config["ALG"]
            + "/trial_"
            + str(TRIAL)
            + "_results.csv",
            header=None,
        )

        print("Average reward for 10 repetitions: %s" % np.mean(results_trial[2].values))

        all_results_trail.append(np.mean(results_trial[2].values))

    print("ALL RESULTS TRAIL:" , all_results_trail)
# Out:
# Config: {'ENV': 'LunarLander-v2', 'ALG': 'FINAL_ICILStudent_replicatedata_trajnum22', 'NUM_TRAJS_GIVEN': 2, 'NUM_TRAINING_ENVS': 2, 'NOISE_DIM': 4, 'REP_SIZE': 16, 'TRAJ_SHIFT': 2, 'SAMPLING_RATE': 5, 'NUM_STEPS_TRAIN': 10000, 'NUM_TRAJS_VALID': 100, 'NUM_REPETITIONS': 15, 'BATCH_SIZE': 64, 'MLP_WIDTHS': 64, 'ADAM_ALPHA': 0.001, 'SGLD_BUFFER_SIZE': 10000, 'SGLD_LEARN_RATE': 0.01, 'SGLD_NOISE_COEF': 0.01, 'SGLD_NUM_STEPS': 100, 'SGLD_REINIT_FREQ': 0.05, 'NUM_STEPS_TRAIN_ENERGY_MODEL': 1000, 'TRIAL': 0, 'METHOD': 'ICIL', 'l2_regularizer_weight': 0.001, 'penalty_weight': 10000, 'penalty_anneal_iters': 2500, 'EXPERT_ALG': 'dqn'}
# Trial number 0
# config method =  ICIL
# config env =  LunarLander-v2
# Run 1 out of 15
# state_dim 12
# 100%|██████████| 1000/1000 [01:14<00:00, 13.41it/s]
# [FeaturesDecoder(
#   (layers): Sequential(
#     (0): Linear(in_features=20, out_features=64, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=64, out_features=16, bias=True)
#   )
# ), FeaturesDecoder(
#   (layers): Sequential(
#     (0): Linear(in_features=20, out_features=64, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=64, out_features=16, bias=True)
#   )
# )]
# self.noise_features_encoders [FeaturesEncoder(
#   (layers): Sequential(
#     (0): Linear(in_features=12, out_features=64, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=64, out_features=16, bias=True)
#   )
# ), FeaturesEncoder(
#   (layers): Sequential(
#     (0): Linear(in_features=12, out_features=64, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=64, out_features=16, bias=True)
#   )
# )]
# 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-8a45523ea3dc> in <module>()
#      64             print("Run %s out of %s" % (run_seed + 1, config["NUM_REPETITIONS"]))
#      65             student = make_student(run_seed, config)
# ---> 66             student.train(num_updates=config["NUM_STEPS_TRAIN"])
#      67
#      68             env_wrapper_out_of_sample = EnvWrapper(
#
# /content/drive/.shortcut-targets-by-id/1OMkIazT1mDvTsmoHYHfcjKlWdwFWLOpV/ImitationLearning/Invariant-Causal-Imitation-Learning-main/student/icil_student.py in train(self, num_updates)
#     121
#     122         for update_index in (range(num_updates)):
# --> 123             self._update_networks()
#     124             if update_index % 1000 == 0:
#     125                 print(update_index)
#
# /content/drive/.shortcut-targets-by-id/1OMkIazT1mDvTsmoHYHfcjKlWdwFWLOpV/ImitationLearning/Invariant-Causal-Imitation-Learning-main/student/icil_student.py in _update_networks(self)
#     147             env_discriminator_loss,
#     148             mine_loss,
# --> 149         ) = self._compute_loss(samples)
#     150
#     151         rep_loss = disc_entropy + next_state_pred_loss + mi_loss
#
# /content/drive/.shortcut-targets-by-id/1OMkIazT1mDvTsmoHYHfcjKlWdwFWLOpV/ImitationLearning/Invariant-Causal-Imitation-Learning-main/student/icil_student.py in _compute_loss(self, samples)
#     205
#     206             noise_rep_env = self.noise_features_encoders[env_id](state_env)
# --> 207             next_state_noise_rep_env = self.noise_features_decoders[env_id](noise_rep_env, action_one_hot_env)
#     208
#     209             noise_rep[env_samples_idx] = noise_rep_env
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/drive/.shortcut-targets-by-id/1OMkIazT1mDvTsmoHYHfcjKlWdwFWLOpV/ImitationLearning/Invariant-Causal-Imitation-Learning-main/network/icil_networks.py in forward(self, x, a)
#      34     def forward(self, x, a):
#      35         input = torch.cat((x, a), dim=-1)
# ---> 36         return self.layers(input)
#      37
#      38
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (28x19 and 20x64)

# %% [markdown]
# #line by line

# %%
config["EXPERT_ALG"] = yaml.load(open("testing/config.yml"), Loader=yaml.FullLoader)[config["ENV"]]
print("Config: %s" % config)


TRIAL = config["TRIAL"] #args.trial
print("Trial number %s" % TRIAL)


results_dir_base = "testing/results/"
results_dir = os.path.join(results_dir_base, config["ENV"], str(config["NUM_TRAJS_GIVEN"]), config["ALG"])


if not os.path.exists(results_dir):
    os.makedirs(results_dir)



config_file = "trial_" + str(TRIAL) + "_" + "config.pkl"

results_file_name = "trial_" + str(TRIAL) + "_" + "results.csv"
results_file_path = os.path.join(results_dir, results_file_name)

if os.path.exists(os.path.join(results_dir, config_file)):
    raise NameError("CONFIG file already exists %s. Choose a different trial number." % config_file)
pickle.dump(config, open(os.path.join(results_dir, config_file), "wb"))
# Out:
# Config: {'ENV': 'CartPole-v1', 'ALG': 'ICILStudent', 'NUM_TRAJS_GIVEN': 10, 'NUM_TRAINING_ENVS': 2, 'NOISE_DIM': 4, 'REP_SIZE': 16, 'TRAJ_SHIFT': 20, 'SAMPLING_RATE': 5, 'NUM_STEPS_TRAIN': 10000, 'NUM_TRAJS_VALID': 100, 'NUM_REPETITIONS': 10, 'BATCH_SIZE': 64, 'MLP_WIDTHS': 64, 'ADAM_ALPHA': 0.001, 'SGLD_BUFFER_SIZE': 10000, 'SGLD_LEARN_RATE': 0.01, 'SGLD_NOISE_COEF': 0.01, 'SGLD_NUM_STEPS': 100, 'SGLD_REINIT_FREQ': 0.05, 'NUM_STEPS_TRAIN_ENERGY_MODEL': 1000, 'TRIAL': 8, 'METHOD': 'BC', 'EXPERT_ALG': 'dqn'}
# Trial number 8

# %%
#"""
if __name__ == "__main__":
   
    print("config method = ", config['METHOD'])
    print("config env = ", config['ENV'])

    for run_seed in range(config["NUM_REPETITIONS"]):
        print("Run %s out of %s" % (run_seed + 1, config["NUM_REPETITIONS"]))
        student = make_student(run_seed, config)
        student.train(num_updates=config["NUM_STEPS_TRAIN"])

        env_wrapper_out_of_sample = EnvWrapper(
            env=gym.make(config["ENV"]), mult_factor=get_test_mult_factors(config['NOISE_DIM'] - 1), idx=3, seed=1
        )
        action_match, return_mean, return_std = student.test(
            num_episodes=config["NUM_TRAJS_VALID"], env_wrapper=env_wrapper_out_of_sample
        )

        result = (action_match, return_mean, return_std)
        print("###############    Reward for test environment for run %s: %s.   ###############\n\n" % (run_seed + 1, return_mean))
        save_results(results_file_path, run_seed, action_match, return_mean, return_std)

    results_trial = pd.read_csv(
        "testing/results/"
        + config["ENV"]
        + "/"
        + str(config["NUM_TRAJS_GIVEN"])
        + "/"
        + config["ALG"]
        + "/trial_"
        + str(TRIAL)
        + "_results.csv",
        header=None,
    )

    print("Average reward for 10 repetitions: %s" % np.mean(results_trial[2].values))
#"""
# Out:
# config method =  BC
# config env =  CartPole-v1
# Run 1 out of 10
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 1: 166.1.   ###############
#
#
# Run 2 out of 10
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 2: 155.74.   ###############
#
#
# Run 3 out of 10
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 3: 496.46.   ###############
#
#
# Run 4 out of 10
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 4: 500.0.   ###############
#
#
# Run 5 out of 10
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 5: 500.0.   ###############
#
#
# Run 6 out of 10
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 6: 274.88.   ###############
#
#
# Run 7 out of 10
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 7: 144.6.   ###############
#
#
# Run 8 out of 10
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 8: 250.22.   ###############
#
#
# Run 9 out of 10
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 9: 355.71.   ###############
#
#
# Run 10 out of 10
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ###############    Reward for test environment for run 10: 500.0.   ###############
#
#
# Average reward for 10 repetitions: 334.371

# %%
#"""
if __name__ == "__main__":
   
    print("config method = ", config['METHOD'])
    print("config env = ", config['ENV'])

    for run_seed in range(config["NUM_REPETITIONS"]):
        print("Run %s out of %s" % (run_seed + 1, config["NUM_REPETITIONS"]))
        student = make_student(run_seed, config)
        student.train(num_updates=config["NUM_STEPS_TRAIN"])

        env_wrapper_out_of_sample = EnvWrapper(
            env=gym.make(config["ENV"]), mult_factor=get_test_mult_factors(config['NOISE_DIM'] - 1), idx=3, seed=1
        )
        action_match, return_mean, return_std = student.test(
            num_episodes=config["NUM_TRAJS_VALID"], env_wrapper=env_wrapper_out_of_sample
        )

        result = (action_match, return_mean, return_std)
        print("###############    Reward for test environment for run %s: %s.   ###############\n\n" % (run_seed + 1, return_mean))
        save_results(results_file_path, run_seed, action_match, return_mean, return_std)

    results_trial = pd.read_csv(
        "testing/results/"
        + config["ENV"]
        + "/"
        + str(config["NUM_TRAJS_GIVEN"])
        + "/"
        + config["ALG"]
        + "/trial_"
        + str(TRIAL)
        + "_results.csv",
        header=None,
    )

    print("Average reward for 10 repetitions: %s" % np.mean(results_trial[2].values))
#"""
# Out:
# config method =  BCIRM
# config env =  CartPole-v1
# Run 1 out of 10
# 200 tensor(0.4755, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.4851, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.4670, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.4648, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.4254, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.5061, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.5847, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.4992, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.3855, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.4569, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.5494, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.3457, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.4519, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.3749, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.5179, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.6392, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.5729, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.3628, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.4296, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4332, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.3463, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.5041, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.4767, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4100, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.3299, device='cuda:0', grad_fn=<AddBackward0>)
# 5200 tensor(0.3975, device='cuda:0', grad_fn=<AddBackward0>)
# 5400 tensor(0.3623, device='cuda:0', grad_fn=<AddBackward0>)
# 5600 tensor(0.4292, device='cuda:0', grad_fn=<AddBackward0>)
# 5800 tensor(0.5904, device='cuda:0', grad_fn=<AddBackward0>)
# 6000 tensor(0.4407, device='cuda:0', grad_fn=<AddBackward0>)
# 6200 tensor(0.3574, device='cuda:0', grad_fn=<AddBackward0>)
# 6400 tensor(0.6357, device='cuda:0', grad_fn=<AddBackward0>)
# 6600 tensor(0.5464, device='cuda:0', grad_fn=<AddBackward0>)
# 6800 tensor(0.4772, device='cuda:0', grad_fn=<AddBackward0>)
# 7000 tensor(0.3592, device='cuda:0', grad_fn=<AddBackward0>)
# 7200 tensor(0.4764, device='cuda:0', grad_fn=<AddBackward0>)
# 7400 tensor(0.4159, device='cuda:0', grad_fn=<AddBackward0>)
# 7600 tensor(0.4034, device='cuda:0', grad_fn=<AddBackward0>)
# 7800 tensor(0.5359, device='cuda:0', grad_fn=<AddBackward0>)
# 8000 tensor(0.4650, device='cuda:0', grad_fn=<AddBackward0>)
# 8200 tensor(0.3551, device='cuda:0', grad_fn=<AddBackward0>)
# 8400 tensor(0.5305, device='cuda:0', grad_fn=<AddBackward0>)
# 8600 tensor(0.4171, device='cuda:0', grad_fn=<AddBackward0>)
# 8800 tensor(0.5143, device='cuda:0', grad_fn=<AddBackward0>)
# 9000 tensor(0.4813, device='cuda:0', grad_fn=<AddBackward0>)
# 9200 tensor(0.4739, device='cuda:0', grad_fn=<AddBackward0>)
# 9400 tensor(0.4078, device='cuda:0', grad_fn=<AddBackward0>)
# 9600 tensor(0.4660, device='cuda:0', grad_fn=<AddBackward0>)
# 9800 tensor(0.4660, device='cuda:0', grad_fn=<AddBackward0>)
# 10000 tensor(0.4968, device='cuda:0', grad_fn=<AddBackward0>)
# ###############    Reward for test environment for run 1: 500.0.   ###############
#
#
# Run 2 out of 10
# 200 tensor(0.4633, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.4356, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.4789, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.4329, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.5328, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.4042, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.5114, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.4908, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.4130, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.4741, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.4827, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.5630, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.4678, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.4623, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.4577, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.4845, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.4523, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.6399, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.4786, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4973, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.4877, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4190, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.4808, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4588, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.4338, device='cuda:0', grad_fn=<AddBackward0>)
# 5200 tensor(0.3918, device='cuda:0', grad_fn=<AddBackward0>)
# 5400 tensor(0.4403, device='cuda:0', grad_fn=<AddBackward0>)
# 5600 tensor(0.5173, device='cuda:0', grad_fn=<AddBackward0>)
# 5800 tensor(0.5245, device='cuda:0', grad_fn=<AddBackward0>)
# 6000 tensor(0.5274, device='cuda:0', grad_fn=<AddBackward0>)
# 6200 tensor(0.6150, device='cuda:0', grad_fn=<AddBackward0>)
# 6400 tensor(0.3348, device='cuda:0', grad_fn=<AddBackward0>)
# 6600 tensor(0.5432, device='cuda:0', grad_fn=<AddBackward0>)
# 6800 tensor(0.4832, device='cuda:0', grad_fn=<AddBackward0>)
# 7000 tensor(0.4507, device='cuda:0', grad_fn=<AddBackward0>)
# 7200 tensor(0.4204, device='cuda:0', grad_fn=<AddBackward0>)
# 7400 tensor(0.3584, device='cuda:0', grad_fn=<AddBackward0>)
# 7600 tensor(0.3819, device='cuda:0', grad_fn=<AddBackward0>)
# 7800 tensor(0.4049, device='cuda:0', grad_fn=<AddBackward0>)
# 8000 tensor(0.4604, device='cuda:0', grad_fn=<AddBackward0>)
# 8200 tensor(0.6376, device='cuda:0', grad_fn=<AddBackward0>)
# 8400 tensor(0.3473, device='cuda:0', grad_fn=<AddBackward0>)
# 8600 tensor(0.5275, device='cuda:0', grad_fn=<AddBackward0>)
# 8800 tensor(0.4467, device='cuda:0', grad_fn=<AddBackward0>)
# 9000 tensor(0.3926, device='cuda:0', grad_fn=<AddBackward0>)
# 9200 tensor(0.4104, device='cuda:0', grad_fn=<AddBackward0>)
# 9400 tensor(0.4646, device='cuda:0', grad_fn=<AddBackward0>)
# 9600 tensor(0.3669, device='cuda:0', grad_fn=<AddBackward0>)
# 9800 tensor(0.3467, device='cuda:0', grad_fn=<AddBackward0>)
# 10000 tensor(0.4640, device='cuda:0', grad_fn=<AddBackward0>)
# ###############    Reward for test environment for run 2: 500.0.   ###############
#
#
# Run 3 out of 10
# 200 tensor(0.4777, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.3941, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.4967, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.4313, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.4369, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.5547, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.3303, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.3486, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.4865, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.3228, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.5105, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.4862, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.3432, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.4114, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.4160, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.3437, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.3623, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.3858, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.5717, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4072, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.3834, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4159, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.3779, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4350, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.3989, device='cuda:0', grad_fn=<AddBackward0>)
# 5200 tensor(0.4276, device='cuda:0', grad_fn=<AddBackward0>)
# 5400 tensor(0.3470, device='cuda:0', grad_fn=<AddBackward0>)
# 5600 tensor(0.4989, device='cuda:0', grad_fn=<AddBackward0>)
# 5800 tensor(0.4314, device='cuda:0', grad_fn=<AddBackward0>)
# 6000 tensor(0.4915, device='cuda:0', grad_fn=<AddBackward0>)
# 6200 tensor(0.3629, device='cuda:0', grad_fn=<AddBackward0>)
# 6400 tensor(0.4534, device='cuda:0', grad_fn=<AddBackward0>)
# 6600 tensor(0.3940, device='cuda:0', grad_fn=<AddBackward0>)
# 6800 tensor(0.4173, device='cuda:0', grad_fn=<AddBackward0>)
# 7000 tensor(0.3554, device='cuda:0', grad_fn=<AddBackward0>)
# 7200 tensor(0.3645, device='cuda:0', grad_fn=<AddBackward0>)
# 7400 tensor(0.5141, device='cuda:0', grad_fn=<AddBackward0>)
# 7600 tensor(0.3534, device='cuda:0', grad_fn=<AddBackward0>)
# 7800 tensor(0.3700, device='cuda:0', grad_fn=<AddBackward0>)
# 8000 tensor(0.4379, device='cuda:0', grad_fn=<AddBackward0>)
# 8200 tensor(0.4646, device='cuda:0', grad_fn=<AddBackward0>)
# 8400 tensor(0.5127, device='cuda:0', grad_fn=<AddBackward0>)
# 8600 tensor(0.3827, device='cuda:0', grad_fn=<AddBackward0>)
# 8800 tensor(0.4894, device='cuda:0', grad_fn=<AddBackward0>)
# 9000 tensor(0.3838, device='cuda:0', grad_fn=<AddBackward0>)
# 9200 tensor(0.4982, device='cuda:0', grad_fn=<AddBackward0>)
# 9400 tensor(0.4258, device='cuda:0', grad_fn=<AddBackward0>)
# 9600 tensor(0.4980, device='cuda:0', grad_fn=<AddBackward0>)
# 9800 tensor(0.4156, device='cuda:0', grad_fn=<AddBackward0>)
# 10000 tensor(0.3742, device='cuda:0', grad_fn=<AddBackward0>)
# ###############    Reward for test environment for run 3: 500.0.   ###############
#
#
# Run 4 out of 10
# 200 tensor(0.4055, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.3889, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.4606, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.3499, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.5976, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.4434, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.4671, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.3102, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.3908, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.5072, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.5751, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.3628, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.4372, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.5374, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.3915, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.2895, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.4264, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.3917, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.4354, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.3937, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.3979, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4320, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.3254, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4601, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.4886, device='cuda:0', grad_fn=<AddBackward0>)
# 5200 tensor(0.4213, device='cuda:0', grad_fn=<AddBackward0>)
# 5400 tensor(0.3349, device='cuda:0', grad_fn=<AddBackward0>)
# 5600 tensor(0.3538, device='cuda:0', grad_fn=<AddBackward0>)
# 5800 tensor(0.3542, device='cuda:0', grad_fn=<AddBackward0>)
# 6000 tensor(0.3519, device='cuda:0', grad_fn=<AddBackward0>)
# 6200 tensor(0.5079, device='cuda:0', grad_fn=<AddBackward0>)
# 6400 tensor(0.4002, device='cuda:0', grad_fn=<AddBackward0>)
# 6600 tensor(0.3187, device='cuda:0', grad_fn=<AddBackward0>)
# 6800 tensor(0.3188, device='cuda:0', grad_fn=<AddBackward0>)
# 7000 tensor(0.4645, device='cuda:0', grad_fn=<AddBackward0>)
# 7200 tensor(0.5227, device='cuda:0', grad_fn=<AddBackward0>)
# 7400 tensor(0.4124, device='cuda:0', grad_fn=<AddBackward0>)
# 7600 tensor(0.3441, device='cuda:0', grad_fn=<AddBackward0>)
# 7800 tensor(0.4814, device='cuda:0', grad_fn=<AddBackward0>)
# 8000 tensor(0.3557, device='cuda:0', grad_fn=<AddBackward0>)
# 8200 tensor(0.3794, device='cuda:0', grad_fn=<AddBackward0>)
# 8400 tensor(0.5175, device='cuda:0', grad_fn=<AddBackward0>)
# 8600 tensor(0.4351, device='cuda:0', grad_fn=<AddBackward0>)
# 8800 tensor(0.3927, device='cuda:0', grad_fn=<AddBackward0>)
# 9000 tensor(0.3817, device='cuda:0', grad_fn=<AddBackward0>)
# 9200 tensor(0.3335, device='cuda:0', grad_fn=<AddBackward0>)
# 9400 tensor(0.3244, device='cuda:0', grad_fn=<AddBackward0>)
# 9600 tensor(0.3683, device='cuda:0', grad_fn=<AddBackward0>)
# 9800 tensor(0.4535, device='cuda:0', grad_fn=<AddBackward0>)
# 10000 tensor(0.3502, device='cuda:0', grad_fn=<AddBackward0>)
# ###############    Reward for test environment for run 4: 500.0.   ###############
#
#
# Run 5 out of 10
# 200 tensor(0.5101, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.5661, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.4944, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.5068, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.4905, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.4803, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.4310, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.5100, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.5218, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.4900, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.5024, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.4781, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.5175, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.4335, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.4572, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.4792, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.4236, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.5360, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.4744, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4448, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.5708, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4116, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.3588, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.3968, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.4405, device='cuda:0', grad_fn=<AddBackward0>)
# 5200 tensor(0.3654, device='cuda:0', grad_fn=<AddBackward0>)
# 5400 tensor(0.5062, device='cuda:0', grad_fn=<AddBackward0>)
# 5600 tensor(0.4260, device='cuda:0', grad_fn=<AddBackward0>)
# 5800 tensor(0.4213, device='cuda:0', grad_fn=<AddBackward0>)
# 6000 tensor(0.3095, device='cuda:0', grad_fn=<AddBackward0>)
# 6200 tensor(0.3962, device='cuda:0', grad_fn=<AddBackward0>)
# 6400 tensor(0.4030, device='cuda:0', grad_fn=<AddBackward0>)
# 6600 tensor(0.4026, device='cuda:0', grad_fn=<AddBackward0>)
# 6800 tensor(0.4156, device='cuda:0', grad_fn=<AddBackward0>)
# 7000 tensor(0.5200, device='cuda:0', grad_fn=<AddBackward0>)
# 7200 tensor(0.4061, device='cuda:0', grad_fn=<AddBackward0>)
# 7400 tensor(0.5446, device='cuda:0', grad_fn=<AddBackward0>)
# 7600 tensor(0.4513, device='cuda:0', grad_fn=<AddBackward0>)
# 7800 tensor(0.4303, device='cuda:0', grad_fn=<AddBackward0>)
# 8000 tensor(0.4575, device='cuda:0', grad_fn=<AddBackward0>)
# 8200 tensor(0.5071, device='cuda:0', grad_fn=<AddBackward0>)
# 8400 tensor(0.5015, device='cuda:0', grad_fn=<AddBackward0>)
# 8600 tensor(0.5341, device='cuda:0', grad_fn=<AddBackward0>)
# 8800 tensor(0.4583, device='cuda:0', grad_fn=<AddBackward0>)
# 9000 tensor(0.4521, device='cuda:0', grad_fn=<AddBackward0>)
# 9200 tensor(0.4509, device='cuda:0', grad_fn=<AddBackward0>)
# 9400 tensor(0.4463, device='cuda:0', grad_fn=<AddBackward0>)
# 9600 tensor(0.4751, device='cuda:0', grad_fn=<AddBackward0>)
# 9800 tensor(0.3832, device='cuda:0', grad_fn=<AddBackward0>)
# 10000 tensor(0.4775, device='cuda:0', grad_fn=<AddBackward0>)
# ###############    Reward for test environment for run 5: 500.0.   ###############
#
#
# Run 6 out of 10
# 200 tensor(0.5242, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.4283, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.4671, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.3733, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.4743, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.4334, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.3921, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.4838, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.4149, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.5421, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.4384, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.4349, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.4971, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.5017, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.3965, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.4337, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.4950, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.3649, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.4068, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4000, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.3948, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4424, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.4057, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4762, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.5721, device='cuda:0', grad_fn=<AddBackward0>)
# 5200 tensor(0.4365, device='cuda:0', grad_fn=<AddBackward0>)
# 5400 tensor(0.4298, device='cuda:0', grad_fn=<AddBackward0>)
# 5600 tensor(0.3593, device='cuda:0', grad_fn=<AddBackward0>)
# 5800 tensor(0.5259, device='cuda:0', grad_fn=<AddBackward0>)
# 6000 tensor(0.6846, device='cuda:0', grad_fn=<AddBackward0>)
# 6200 tensor(0.3737, device='cuda:0', grad_fn=<AddBackward0>)
# 6400 tensor(0.4221, device='cuda:0', grad_fn=<AddBackward0>)
# 6600 tensor(0.4174, device='cuda:0', grad_fn=<AddBackward0>)
# 6800 tensor(0.3716, device='cuda:0', grad_fn=<AddBackward0>)
# 7000 tensor(0.4892, device='cuda:0', grad_fn=<AddBackward0>)
# 7200 tensor(0.6121, device='cuda:0', grad_fn=<AddBackward0>)
# 7400 tensor(0.5533, device='cuda:0', grad_fn=<AddBackward0>)
# 7600 tensor(0.3168, device='cuda:0', grad_fn=<AddBackward0>)
# 7800 tensor(0.3936, device='cuda:0', grad_fn=<AddBackward0>)
# 8000 tensor(0.4069, device='cuda:0', grad_fn=<AddBackward0>)
# 8200 tensor(0.4179, device='cuda:0', grad_fn=<AddBackward0>)
# 8400 tensor(0.5282, device='cuda:0', grad_fn=<AddBackward0>)
# 8600 tensor(0.3875, device='cuda:0', grad_fn=<AddBackward0>)
# 8800 tensor(0.3617, device='cuda:0', grad_fn=<AddBackward0>)
# 9000 tensor(0.4657, device='cuda:0', grad_fn=<AddBackward0>)
# 9200 tensor(0.3939, device='cuda:0', grad_fn=<AddBackward0>)
# 9400 tensor(0.4217, device='cuda:0', grad_fn=<AddBackward0>)
# 9600 tensor(0.4849, device='cuda:0', grad_fn=<AddBackward0>)
# 9800 tensor(0.5560, device='cuda:0', grad_fn=<AddBackward0>)
# 10000 tensor(0.6484, device='cuda:0', grad_fn=<AddBackward0>)
# ###############    Reward for test environment for run 6: 500.0.   ###############
#
#
# Run 7 out of 10
# 200 tensor(0.5311, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.5440, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.5003, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.3614, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.4028, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.5195, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.5241, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.4075, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.4812, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.4508, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.4922, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.5194, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.4981, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.3745, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.4308, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.4742, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.4162, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.4566, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.5212, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4498, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.5146, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4515, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.3820, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.5623, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.4734, device='cuda:0', grad_fn=<AddBackward0>)
# 5200 tensor(0.4364, device='cuda:0', grad_fn=<AddBackward0>)
# 5400 tensor(0.4352, device='cuda:0', grad_fn=<AddBackward0>)
# 5600 tensor(0.4232, device='cuda:0', grad_fn=<AddBackward0>)
# 5800 tensor(0.6189, device='cuda:0', grad_fn=<AddBackward0>)
# 6000 tensor(0.4834, device='cuda:0', grad_fn=<AddBackward0>)
# 6200 tensor(0.3909, device='cuda:0', grad_fn=<AddBackward0>)
# 6400 tensor(0.4605, device='cuda:0', grad_fn=<AddBackward0>)
# 6600 tensor(0.4030, device='cuda:0', grad_fn=<AddBackward0>)
# 6800 tensor(0.5104, device='cuda:0', grad_fn=<AddBackward0>)
# 7000 tensor(0.3355, device='cuda:0', grad_fn=<AddBackward0>)
# 7200 tensor(0.4352, device='cuda:0', grad_fn=<AddBackward0>)
# 7400 tensor(0.3968, device='cuda:0', grad_fn=<AddBackward0>)
# 7600 tensor(0.3954, device='cuda:0', grad_fn=<AddBackward0>)
# 7800 tensor(0.4083, device='cuda:0', grad_fn=<AddBackward0>)
# 8000 tensor(0.4171, device='cuda:0', grad_fn=<AddBackward0>)
# 8200 tensor(0.5096, device='cuda:0', grad_fn=<AddBackward0>)
# 8400 tensor(0.4177, device='cuda:0', grad_fn=<AddBackward0>)
# 8600 tensor(0.4559, device='cuda:0', grad_fn=<AddBackward0>)
# 8800 tensor(0.4161, device='cuda:0', grad_fn=<AddBackward0>)
# 9000 tensor(0.3261, device='cuda:0', grad_fn=<AddBackward0>)
# 9200 tensor(0.4317, device='cuda:0', grad_fn=<AddBackward0>)
# 9400 tensor(0.4830, device='cuda:0', grad_fn=<AddBackward0>)
# 9600 tensor(0.3788, device='cuda:0', grad_fn=<AddBackward0>)
# 9800 tensor(0.5477, device='cuda:0', grad_fn=<AddBackward0>)
# 10000 tensor(0.4372, device='cuda:0', grad_fn=<AddBackward0>)
# ###############    Reward for test environment for run 7: 500.0.   ###############
#
#
# Run 8 out of 10
# 200 tensor(0.4996, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.4832, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.4116, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.4379, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.5477, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.4906, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.4750, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.4457, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.4254, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.5194, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.3465, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.4050, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.4509, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.4819, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.5030, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.4792, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.4285, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.4628, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.4397, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.3735, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.5094, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4456, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.5018, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4479, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.4028, device='cuda:0', grad_fn=<AddBackward0>)
# 5200 tensor(0.4805, device='cuda:0', grad_fn=<AddBackward0>)
# 5400 tensor(0.4057, device='cuda:0', grad_fn=<AddBackward0>)
# 5600 tensor(0.4615, device='cuda:0', grad_fn=<AddBackward0>)
# 5800 tensor(0.4811, device='cuda:0', grad_fn=<AddBackward0>)
# 6000 tensor(0.4588, device='cuda:0', grad_fn=<AddBackward0>)
# 6200 tensor(0.4159, device='cuda:0', grad_fn=<AddBackward0>)
# 6400 tensor(0.3645, device='cuda:0', grad_fn=<AddBackward0>)
# 6600 tensor(0.4662, device='cuda:0', grad_fn=<AddBackward0>)
# 6800 tensor(0.4364, device='cuda:0', grad_fn=<AddBackward0>)
# 7000 tensor(0.5097, device='cuda:0', grad_fn=<AddBackward0>)
# 7200 tensor(0.3663, device='cuda:0', grad_fn=<AddBackward0>)
# 7400 tensor(0.5068, device='cuda:0', grad_fn=<AddBackward0>)
# 7600 tensor(0.4684, device='cuda:0', grad_fn=<AddBackward0>)
# 7800 tensor(0.5493, device='cuda:0', grad_fn=<AddBackward0>)
# 8000 tensor(0.4219, device='cuda:0', grad_fn=<AddBackward0>)
# 8200 tensor(0.4671, device='cuda:0', grad_fn=<AddBackward0>)
# 8400 tensor(0.3976, device='cuda:0', grad_fn=<AddBackward0>)
# 8600 tensor(0.5095, device='cuda:0', grad_fn=<AddBackward0>)
# 8800 tensor(0.4081, device='cuda:0', grad_fn=<AddBackward0>)
# 9000 tensor(0.3286, device='cuda:0', grad_fn=<AddBackward0>)
# 9200 tensor(0.3659, device='cuda:0', grad_fn=<AddBackward0>)
# 9400 tensor(0.4363, device='cuda:0', grad_fn=<AddBackward0>)
# 9600 tensor(0.3921, device='cuda:0', grad_fn=<AddBackward0>)
# 9800 tensor(0.4081, device='cuda:0', grad_fn=<AddBackward0>)
# 10000 tensor(0.4465, device='cuda:0', grad_fn=<AddBackward0>)
# ###############    Reward for test environment for run 8: 500.0.   ###############
#
#
# Run 9 out of 10
# 200 tensor(0.4446, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.4197, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.4441, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.4154, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.5217, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.3868, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.4100, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.4190, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.5266, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.4214, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.3395, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.5406, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.3410, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.3722, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.3980, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.4600, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.3514, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.4112, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.3473, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4019, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.4342, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4383, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.3476, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.4804, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.3792, device='cuda:0', grad_fn=<AddBackward0>)
# 5200 tensor(0.3714, device='cuda:0', grad_fn=<AddBackward0>)
# 5400 tensor(0.4491, device='cuda:0', grad_fn=<AddBackward0>)
# 5600 tensor(0.3453, device='cuda:0', grad_fn=<AddBackward0>)
# 5800 tensor(0.3604, device='cuda:0', grad_fn=<AddBackward0>)
# 6000 tensor(0.3952, device='cuda:0', grad_fn=<AddBackward0>)
# 6200 tensor(0.3530, device='cuda:0', grad_fn=<AddBackward0>)
# 6400 tensor(0.3499, device='cuda:0', grad_fn=<AddBackward0>)
# 6600 tensor(0.4078, device='cuda:0', grad_fn=<AddBackward0>)
# 6800 tensor(0.4009, device='cuda:0', grad_fn=<AddBackward0>)
# 7000 tensor(0.5377, device='cuda:0', grad_fn=<AddBackward0>)
# 7200 tensor(0.3385, device='cuda:0', grad_fn=<AddBackward0>)
# 7400 tensor(0.3533, device='cuda:0', grad_fn=<AddBackward0>)
# 7600 tensor(0.2860, device='cuda:0', grad_fn=<AddBackward0>)
# 7800 tensor(0.3732, device='cuda:0', grad_fn=<AddBackward0>)
# 8000 tensor(0.4586, device='cuda:0', grad_fn=<AddBackward0>)
# 8200 tensor(0.4152, device='cuda:0', grad_fn=<AddBackward0>)
# 8400 tensor(0.3663, device='cuda:0', grad_fn=<AddBackward0>)
# 8600 tensor(0.3970, device='cuda:0', grad_fn=<AddBackward0>)
# 8800 tensor(0.4055, device='cuda:0', grad_fn=<AddBackward0>)
# 9000 tensor(0.3401, device='cuda:0', grad_fn=<AddBackward0>)
# 9200 tensor(0.3687, device='cuda:0', grad_fn=<AddBackward0>)
# 9400 tensor(0.4331, device='cuda:0', grad_fn=<AddBackward0>)
# 9600 tensor(0.4327, device='cuda:0', grad_fn=<AddBackward0>)
# 9800 tensor(0.3229, device='cuda:0', grad_fn=<AddBackward0>)
# 10000 tensor(0.4022, device='cuda:0', grad_fn=<AddBackward0>)
# ###############    Reward for test environment for run 9: 500.0.   ###############
#
#
# Run 10 out of 10
# 200 tensor(0.5783, device='cuda:0', grad_fn=<AddBackward0>)
# 400 tensor(0.5127, device='cuda:0', grad_fn=<AddBackward0>)
# 600 tensor(0.6127, device='cuda:0', grad_fn=<AddBackward0>)
# 800 tensor(0.4535, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 tensor(0.4916, device='cuda:0', grad_fn=<AddBackward0>)
# 1200 tensor(0.4756, device='cuda:0', grad_fn=<AddBackward0>)
# 1400 tensor(0.3963, device='cuda:0', grad_fn=<AddBackward0>)
# 1600 tensor(0.4793, device='cuda:0', grad_fn=<AddBackward0>)
# 1800 tensor(0.8120, device='cuda:0', grad_fn=<AddBackward0>)
# 2000 tensor(0.4294, device='cuda:0', grad_fn=<AddBackward0>)
# 2200 tensor(0.5630, device='cuda:0', grad_fn=<AddBackward0>)
# 2400 tensor(0.4126, device='cuda:0', grad_fn=<AddBackward0>)
# 2600 tensor(0.4683, device='cuda:0', grad_fn=<AddBackward0>)
# 2800 tensor(0.5448, device='cuda:0', grad_fn=<AddBackward0>)
# 3000 tensor(0.5140, device='cuda:0', grad_fn=<AddBackward0>)
# 3200 tensor(0.5784, device='cuda:0', grad_fn=<AddBackward0>)
# 3400 tensor(0.3458, device='cuda:0', grad_fn=<AddBackward0>)
# 3600 tensor(0.6900, device='cuda:0', grad_fn=<AddBackward0>)
# 3800 tensor(0.5784, device='cuda:0', grad_fn=<AddBackward0>)
# 4000 tensor(0.4420, device='cuda:0', grad_fn=<AddBackward0>)
# 4200 tensor(0.5287, device='cuda:0', grad_fn=<AddBackward0>)
# 4400 tensor(0.4385, device='cuda:0', grad_fn=<AddBackward0>)
# 4600 tensor(0.4884, device='cuda:0', grad_fn=<AddBackward0>)
# 4800 tensor(0.5089, device='cuda:0', grad_fn=<AddBackward0>)
# 5000 tensor(0.3094, device='cuda:0', grad_fn=<AddBackward0>)
# 5200 tensor(0.4566, device='cuda:0', grad_fn=<AddBackward0>)
# 5400 tensor(0.4584, device='cuda:0', grad_fn=<AddBackward0>)
# 5600 tensor(0.5061, device='cuda:0', grad_fn=<AddBackward0>)
# 5800 tensor(0.4770, device='cuda:0', grad_fn=<AddBackward0>)
# 6000 tensor(0.3909, device='cuda:0', grad_fn=<AddBackward0>)
# 6200 tensor(0.5923, device='cuda:0', grad_fn=<AddBackward0>)
# 6400 tensor(0.5265, device='cuda:0', grad_fn=<AddBackward0>)
# 6600 tensor(0.4626, device='cuda:0', grad_fn=<AddBackward0>)
# 6800 tensor(0.4599, device='cuda:0', grad_fn=<AddBackward0>)
# 7000 tensor(0.6071, device='cuda:0', grad_fn=<AddBackward0>)
# 7200 tensor(0.4436, device='cuda:0', grad_fn=<AddBackward0>)
# 7400 tensor(0.4251, device='cuda:0', grad_fn=<AddBackward0>)
# 7600 tensor(0.4227, device='cuda:0', grad_fn=<AddBackward0>)
# 7800 tensor(0.4851, device='cuda:0', grad_fn=<AddBackward0>)
# 8000 tensor(0.3918, device='cuda:0', grad_fn=<AddBackward0>)
# 8200 tensor(0.4012, device='cuda:0', grad_fn=<AddBackward0>)
# 8400 tensor(0.4658, device='cuda:0', grad_fn=<AddBackward0>)
# 8600 tensor(0.4172, device='cuda:0', grad_fn=<AddBackward0>)
# 8800 tensor(0.5353, device='cuda:0', grad_fn=<AddBackward0>)
# 9000 tensor(0.3854, device='cuda:0', grad_fn=<AddBackward0>)
# 9200 tensor(0.3747, device='cuda:0', grad_fn=<AddBackward0>)
# 9400 tensor(0.3918, device='cuda:0', grad_fn=<AddBackward0>)
# 9600 tensor(0.4321, device='cuda:0', grad_fn=<AddBackward0>)
# 9800 tensor(0.4465, device='cuda:0', grad_fn=<AddBackward0>)
# 10000 tensor(0.4670, device='cuda:0', grad_fn=<AddBackward0>)
# ###############    Reward for test environment for run 10: 500.0.   ###############
#
#
# Average reward for 10 repetitions: 500.0

# %% [markdown]
# # *** *core* *** generate expert_traj_i

# %%
def get_train_spurcorr_expert_trajs(datafile_name, env_name,  _noise = 0.001,  num_envs = 2):

    from tqdm import tqdm 
    import numpy as np

    def generate_spurcorr_obs(observations, _mult_factor, _noise = 0.001, _idx = 0):
        noise_dims = len(_mult_factor)
        #obs_noise = np.zeros_like(observations)
        #obs_noise[-noise_dims:] = np.random.randn(noise_dims) * _noise
        spur_corr = np.matmul(observations[-noise_dims:], _mult_factor)
        #obs = np.concatenate([observations + obs_noise, spur_corr, [_idx]])
        obs = np.concatenate([observations , spur_corr + np.random.randn(noise_dims) * _noise, [_idx]])
        return obs

    raw = np.load(datafile_name, allow_pickle = True)#[()]#["trajs"]

    obs_dim = len(raw['obs'][0])
    obs_num = len(raw['obs'])

    for expert_num in range(num_envs):
        # print(_mult_factor_multipliers[expert_num])
            
        obs_new = np.zeros(shape = (obs_num, obs_dim *2))

        #_mult_factor = np.diag(np.ones(obs_dim-1)) * _mult_factor_multipliers[expert_num]
        if expert_num ==0:
            _mult_factor = np.diag(np.ones(obs_dim-1))
        elif expert_num ==1:
            _mult_factor = np.ones((obs_dim-1, obs_dim-1)) + np.diag(np.ones(obs_dim-1))


        for i in tqdm(range(obs_num)):
            obs_new[i] = generate_spurcorr_obs(raw['obs'][i], _mult_factor, _noise = 0.001, _idx = expert_num)


        start_index = np.where(raw['episode_starts'] == 1)[0]

        data_block = []
        for i in range(len(start_index)-1):
            slice_idx = np.arange(start_index[i], start_index[i+1])

            obs = obs_new[slice_idx]
            actions = raw['actions'][slice_idx]

            data_list = []
            for j in range(len(slice_idx)):
                data_list.append( (obs[j], actions[j][0], expert_num) )

            data_block.append(data_list)

        data_generated = {'trajs': data_block}  


        isExist = os.path.exists("./volume/" + env_name)
        if not isExist:
            # Create a new directory because it does not exist 
            os.makedirs("./volume/" + env_name)
            print("The new directory for {} is created!".format(env_name))


        np.save("./volume/" + env_name + '/expert_trajs_' + str(expert_num) + '.npy', data_generated)
        print("\n{} saved!".format("./volume/" + env_name + '/expert_trajs_' + str(expert_num) + '.npy'))
        
    #return data_generated

# %%
np.ones((obs_dim-1, obs_dim-1)) + np.diag(np.ones(obs_dim-1))
# Out:
# array([[2., 1., 1.],
#        [1., 2., 1.],
#        [1., 1., 2.]])

# %%
import os
os.getcwd()

raw = np.load(datafile_name, allow_pickle = True)
obs_dim = len(raw['obs'][0])
obs_num = len(raw['obs'])

(raw['episode_starts'] == 1).sum()
# Out:
# 1000

# %%
#datafile_name = "expert_lunarlander_timesteps2e5_episodes10.npz"
#datafile_name = 'expert_cartpole_timesteps2e5_episodes10.npz'
#datafile_name = './contrib/expert_replicate/' + 'expert_cartpole_dqn_replicate_episodes1000.npz'
datafile_name = './contrib/expert_replicate/' + 'expert_lunarlander_ppo2_replicate_episodes1000.npz'



env_name = 'LunarLander-v2'
#env_name = 'CartPole-v1'

get_train_spurcorr_expert_trajs(datafile_name, env_name = env_name,  _noise = 0.001, num_envs = 2)
# Out:
#   0%|          | 0/902005 [00:00<?, ?it/s]
#   0%|          | 3/902005 [00:00<11:15:03, 22.27it/s]
#   0%|          | 5/902005 [00:00<11:38:04, 21.54it/s]
#   0%|          | 8/902005 [00:00<11:35:07, 21.63it/s]
#   0%|          | 11/902005 [00:00<11:29:04, 21.82it/s]
#   0%|          | 14/902005 [00:00<11:27:21, 21.87it/s]
#   0%|          | 17/902005 [00:00<11:26:43, 21.89it/s]
#   0%|          | 19/902005 [00:00<11:52:15, 21.11it/s]
#   0%|          | 22/902005 [00:01<11:48:50, 21.21it/s]
#   0%|          | 25/902005 [00:01<11:44:49, 21.33it/s]
#   0%|          | 28/902005 [00:01<11:48:11, 21.23it/s]
#   0%|          | 31/902005 [00:01<11:55:39, 21.01it/s]
#   0%|          | 34/902005 [00:01<11:56:12, 20.99it/s]
#   0%|          | 37/902005 [00:01<11:51:06, 21.14it/s]
#   0%|          | 40/902005 [00:01<11:56:15, 20.99it/s]
#   0%|          | 43/902005 [00:02<11:47:26, 21.25it/s]
#   0%|          | 46/902005 [00:02<11:44:04, 21.35it/s]
#   0%|          | 49/902005 [00:02<11:39:50, 21.48it/s]
#   0%|          | 52/902005 [00:02<11:37:20, 21.56it/s]
#   0%|          | 55/902005 [00:02<11:34:24, 21.65it/s]
#   0%|          | 58/902005 [00:02<11:31:46, 21.73it/s]
#   0%|          | 61/902005 [00:02<11:29:16, 21.81it/s]
#   0%|          | 64/902005 [00:02<11:38:21, 21.53it/s]
#   0%|          | 67/902005 [00:03<11:38:58, 21.51it/s]
#   0%|          | 70/902005 [00:03<11:38:11, 21.53it/s]
#   0%|          | 73/902005 [00:03<11:33:09, 21.69it/s]
#   0%|          | 76/902005 [00:03<11:29:16, 21.81it/s]
#   0%|          | 79/902005 [00:03<11:29:37, 21.80it/s]
#   0%|          | 82/902005 [00:03<11:26:30, 21.90it/s]
#   0%|          | 85/902005 [00:03<11:36:50, 21.57it/s]
#   0%|          | 88/902005 [00:04<11:37:28, 21.55it/s]
#   0%|          | 91/902005 [00:04<11:36:01, 21.60it/s]
#   0%|          | 94/902005 [00:04<11:30:36, 21.77it/s]
#   0%|          | 97/902005 [00:04<11:25:33, 21.93it/s]
#   0%|          | 100/902005 [00:04<11:26:36, 21.89it/s]
#   0%|          | 103/902005 [00:04<11:32:59, 21.69it/s]
#   0%|          | 106/902005 [00:04<11:33:27, 21.68it/s]
#   0%|          | 109/902005 [00:05<11:27:17, 21.87it/s]
#   0%|          | 112/902005 [00:05<11:27:04, 21.88it/s]
#   0%|          | 115/902005 [00:05<11:26:43, 21.89it/s]
#   0%|          | 118/902005 [00:05<11:22:23, 22.03it/s]
#   0%|          | 121/902005 [00:05<11:19:36, 22.12it/s]
#   0%|          | 124/902005 [00:05<11:20:06, 22.10it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-ecdccd885dfa> in <module>()
#       9 #env_name = 'CartPole-v1'
#      10
# ---> 11 get_train_spurcorr_expert_trajs(datafile_name, env_name = env_name,  _noise = 0.001, num_envs = 2)
#
# <ipython-input-35-10ee4cb98c15> in get_train_spurcorr_expert_trajs(datafile_name, env_name, _noise, num_envs)
#      34
#      35         for i in tqdm(range(obs_num)):
# ---> 36             obs_new[i] = generate_spurcorr_obs(raw['obs'][i], _mult_factor, _noise = 0.001, _idx = expert_num)
#      37
#      38
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     260                 return format.read_array(bytes,
#     261                                          allow_pickle=self.allow_pickle,
# --> 262                                          pickle_kwargs=self.pickle_kwargs)
#     263             else:
#     264                 return self.zip.read(key)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     775                     read_count = min(max_read_count, count - i)
#     776                     read_size = int(read_count * dtype.itemsize)
# --> 777                     data = _read_bytes(fp, read_size, "array data")
#     778                     array[i:i+read_count] = numpy.frombuffer(data, dtype=dtype,
#     779                                                              count=read_count)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/format.py in _read_bytes(fp, size, error_template)
#     904         # done about that.  note that regular files can't be non-blocking
#     905         try:
# --> 906             r = fp.read(size - len(data))
#     907             data += r
#     908             if len(r) == 0 or len(data) == size:
#
# /usr/lib/python3.7/zipfile.py in read(self, n)
#     928         self._offset = 0
#     929         while n > 0 and not self._eof:
# --> 930             data = self._read1(n)
#     931             if n < len(data):
#     932                 self._readbuffer = data
#
# /usr/lib/python3.7/zipfile.py in _read1(self, n)
#    1018         if self._left <= 0:
#    1019             self._eof = True
# -> 1020         self._update_crc(data)
#    1021         return data
#    1022
#
# /usr/lib/python3.7/zipfile.py in _update_crc(self, newdata)
#     943             # No need to compute the CRC if we don't have a reference value
#     944             return
# --> 945         self._running_crc = crc32(newdata, self._running_crc)
#     946         # Check the CRC if we're at the end of the file
#     947         if self._eof and self._running_crc != self._expected_crc:
#
# KeyboardInterrupt:

# %%
data1 = np.load("./volume/CartPole-v1/expert_trajs_1.npy", allow_pickle = True)#[()]#["trajs"]
for key in data1[()]:
  print(key)
# Out:
# trajs
